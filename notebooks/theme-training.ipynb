# %%
# !pip install datasets
# !pip install --upgrade arabic-reshaper
# !pip install python-bidi
# !pip install git+https://github.com/ARBML/tnkeeh.git
# !pip install git+https://github.com/ARBML/tkseem.git
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.25.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0
# Requirement already satisfied: python-bidi in /opt/conda/lib/python3.10/site-packages (0.6.0)
# Collecting git+https://github.com/ARBML/tnkeeh.git
#   Cloning https://github.com/ARBML/tnkeeh.git to /tmp/pip-req-build-4m23h4w9
#   Running command git clone --filter=blob:none --quiet https://github.com/ARBML/tnkeeh.git /tmp/pip-req-build-4m23h4w9
#   Resolved https://github.com/ARBML/tnkeeh.git to commit f23d505f34030db7dc70b05e1ae3576b5d485725
#   Preparing metadata (setup.py) ... done
# Collecting farasapy (from tnkeeh==0.1.0)
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from tnkeeh==0.1.0) (3.0.0)
# Requirement already satisfied: transformers[sentencepiece] in /opt/conda/lib/python3.10/site-packages (from tnkeeh==0.1.0) (4.44.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->tnkeeh==0.1.0) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (0.25.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (0.19.1)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (0.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets->tnkeeh==0.1.0) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets->tnkeeh==0.1.0) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->tnkeeh==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->tnkeeh==0.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->tnkeeh==0.1.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->tnkeeh==0.1.0) (1.16.0)
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Building wheels for collected packages: tnkeeh
#   Building wheel for tnkeeh (setup.py) ... done
#   Created wheel for tnkeeh: filename=tnkeeh-0.1.0-py3-none-any.whl size=8844 sha256=23b2504031c119ecabed9e7964e5ef115febe4fbaf564c5549fbbf9019f4d4b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5x26jnqv/wheels/7e/6f/72/82dc0664f6785a5206a12008834fad9f01ab2c9d3aadb0f661
# Successfully built tnkeeh
# Installing collected packages: farasapy, tnkeeh
# Successfully installed farasapy-0.0.14 tnkeeh-0.1.0
# Collecting git+https://github.com/ARBML/tkseem.git
#   Cloning https://github.com/ARBML/tkseem.git to /tmp/pip-req-build-gupl0urb
#   Running command git clone --filter=blob:none --quiet https://github.com/ARBML/tkseem.git /tmp/pip-req-build-gupl0urb
#   Resolved https://github.com/ARBML/tkseem.git to commit 8532d3c27936b0ee34d79fa48d6e99f2aaef1bc2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (0.2.0)
# Requirement already satisfied: farasapy in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (0.0.14)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (4.66.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (1.26.4)
# Collecting black (from tkseem==0.0.3)
#   Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (1.0.0)
# Collecting packaging>=22.0 (from black->tkseem==0.0.3)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pathspec>=0.9.0 (from black->tkseem==0.0.3)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (3.11.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from farasapy->tkseem==0.0.3) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (2024.8.30)
# Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 41.5 MB/s eta 0:00:0000:01
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.5 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Building wheels for collected packages: tkseem
#   Building wheel for tkseem (setup.py) ... done
#   Created wheel for tkseem: filename=tkseem-0.0.3-py3-none-any.whl size=30855612 sha256=701672e6e6b49fa7afc8db0066e713110f885259d75553a754b20bcaf89a33a6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b8wja3pp/wheels/3f/51/fe/8ebf98170e16d97756de4084d4492165ec9a4024e1a79c4b32
# Successfully built tkseem
# Installing collected packages: pathspec, packaging, black, tkseem
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.0 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.1 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.0 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed black-24.8.0 packaging-24.1 pathspec-0.12.1 tkseem-0.0.3

# %%
import pandas as pd
import json
import datasets
ashaar = datasets.load_dataset('MagedSaeed/ashaar')
# Out:
# README.md:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/34.7k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/126M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/151M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/254630 [00:00<?, ? examples/s]

# %%
df = ashaar['train'].to_pandas()
df
# Out:
#                        poem title       poem meter  \
# 0       أصبح الملك للذي فطر الخلق       بحر الخفيف
# 1                من أي مولى ارتجي  بحر مجزوء الرمل
# 2       العبد عبدك يا من أنت سيده       بحر البسيط
# 3       لو كنت أطمع بالمنام توهما       بحر الكامل
# 4            يعد علي أنفاسي ذنوبا       بحر الوافر
# ...                           ...              ...
# 254625                       None          المضارع
# 254626                       None          المضارع
# 254627                       None          المضارع
# 254628                       None          المضارع
# 254629                       None          المضارع
#
#                                               poem verses   poem theme  \
# 0       [أَصبَحَ المُلك لِلَّذي فَطر الخَل, قَ بِتَقدي...  قصيدة دينية
# 1       [مِن أَي مَولى اِرتَجي, وَلاي باب التَجي, وَال...  قصيدة دينية
# 2       [العَبد عَبدك يا مَن أَنتَ سَيدهُ, وَلَيسَ غَي...     قصيدة ذم
# 3       [لَو كُنتَ أَطمَع بِالمَنام تَوهما, لَسالَت طَ...   قصيدة عامه
# 4       [يعد عَليَّ أَنفاسي ذُنوباً, إِذا ما قُلت أَفد...   قصيدة عامه
# ...                                                   ...          ...
# 254625                [وعندنا ليس محض, إلى الشرق أن تولي]         None
# 254626                  [من الليالي نهار, ومن عتمها ضياء]         None
# 254627                 [مقامه إذ تجلى, وفي البيد إذ تحلى]         None
# 254628  [على بابك انتظرنا, وفي البال ألف حيلة, من الوص...         None
# 254629  [خذ الصفر لا تبالي, فللصفر للرجال, وليس في ذاك...         None
#
#                                       poem url           poet name  \
# 0       https://www.aldiwan.net/poem16182.html    الامير منجك باشا
# 1       https://www.aldiwan.net/poem16183.html    الامير منجك باشا
# 2       https://www.aldiwan.net/poem16184.html    الامير منجك باشا
# 3       https://www.aldiwan.net/poem16185.html    الامير منجك باشا
# 4       https://www.aldiwan.net/poem16186.html    الامير منجك باشا
# ...                                        ...                 ...
# 254625                                    None  dataset collectors
# 254626                                    None  dataset collectors
# 254627                                    None  dataset collectors
# 254628                                    None  dataset collectors
# 254629                                    None  dataset collectors
#
#                                          poet description  \
# 0       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 1       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 2       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 3       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 4       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# ...                                                   ...
# 254625                                               None
# 254626                                               None
# 254627                                               None
# 254628                                               None
# 254629                                               None
#
#                                                  poet url        poet era  \
# 0       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 1       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 2       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 3       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 4       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# ...                                                   ...             ...
# 254625                                               None            None
# 254626                                               None            None
# 254627                                               None            None
# 254628                                               None            None
# 254629                                               None            None
#
#        poet location poem description poem language type
# 0               None             None               None
# 1               None             None               None
# 2               None             None               None
# 3               None             None               None
# 4               None             None               None
# ...              ...              ...                ...
# 254625          None             None               فصيح
# 254626          None             None               فصيح
# 254627          None             None               فصيح
# 254628          None             None               فصيح
# 254629          None             None               فصيح
#
# [254630 rows x 12 columns]

# %%
# always work on a copy :)
df_copy = df.copy(deep=True)
df_copy['poem count'] = df_copy['poem verses'].apply(lambda poem: len(poem)/2)
df_copy['poem verses str'] = df_copy['poem verses'].apply(lambda verses: ' '.join(verse for verse in verses))
len(df_copy)
# Out:
# 254630

# %%
df_copy
# Out:
#                        poem title       poem meter  \
# 0       أصبح الملك للذي فطر الخلق       بحر الخفيف
# 1                من أي مولى ارتجي  بحر مجزوء الرمل
# 2       العبد عبدك يا من أنت سيده       بحر البسيط
# 3       لو كنت أطمع بالمنام توهما       بحر الكامل
# 4            يعد علي أنفاسي ذنوبا       بحر الوافر
# ...                           ...              ...
# 254625                       None          المضارع
# 254626                       None          المضارع
# 254627                       None          المضارع
# 254628                       None          المضارع
# 254629                       None          المضارع
#
#                                               poem verses   poem theme  \
# 0       [أَصبَحَ المُلك لِلَّذي فَطر الخَل, قَ بِتَقدي...  قصيدة دينية
# 1       [مِن أَي مَولى اِرتَجي, وَلاي باب التَجي, وَال...  قصيدة دينية
# 2       [العَبد عَبدك يا مَن أَنتَ سَيدهُ, وَلَيسَ غَي...     قصيدة ذم
# 3       [لَو كُنتَ أَطمَع بِالمَنام تَوهما, لَسالَت طَ...   قصيدة عامه
# 4       [يعد عَليَّ أَنفاسي ذُنوباً, إِذا ما قُلت أَفد...   قصيدة عامه
# ...                                                   ...          ...
# 254625                [وعندنا ليس محض, إلى الشرق أن تولي]         None
# 254626                  [من الليالي نهار, ومن عتمها ضياء]         None
# 254627                 [مقامه إذ تجلى, وفي البيد إذ تحلى]         None
# 254628  [على بابك انتظرنا, وفي البال ألف حيلة, من الوص...         None
# 254629  [خذ الصفر لا تبالي, فللصفر للرجال, وليس في ذاك...         None
#
#                                       poem url           poet name  \
# 0       https://www.aldiwan.net/poem16182.html    الامير منجك باشا
# 1       https://www.aldiwan.net/poem16183.html    الامير منجك باشا
# 2       https://www.aldiwan.net/poem16184.html    الامير منجك باشا
# 3       https://www.aldiwan.net/poem16185.html    الامير منجك باشا
# 4       https://www.aldiwan.net/poem16186.html    الامير منجك باشا
# ...                                        ...                 ...
# 254625                                    None  dataset collectors
# 254626                                    None  dataset collectors
# 254627                                    None  dataset collectors
# 254628                                    None  dataset collectors
# 254629                                    None  dataset collectors
#
#                                          poet description  \
# 0       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 1       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 2       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 3       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 4       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# ...                                                   ...
# 254625                                               None
# 254626                                               None
# 254627                                               None
# 254628                                               None
# 254629                                               None
#
#                                                  poet url        poet era  \
# 0       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 1       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 2       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 3       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 4       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# ...                                                   ...             ...
# 254625                                               None            None
# 254626                                               None            None
# 254627                                               None            None
# 254628                                               None            None
# 254629                                               None            None
#
#        poet location poem description poem language type  poem count  \
# 0               None             None               None        10.0
# 1               None             None               None        15.0
# 2               None             None               None        12.5
# 3               None             None               None        27.0
# 4               None             None               None        21.0
# ...              ...              ...                ...         ...
# 254625          None             None               فصيح         1.0
# 254626          None             None               فصيح         1.0
# 254627          None             None               فصيح         1.0
# 254628          None             None               فصيح         2.0
# 254629          None             None               فصيح         2.0
#
#                                           poem verses str
# 0       أَصبَحَ المُلك لِلَّذي فَطر الخَل قَ بِتَقديرٍ...
# 1       مِن أَي مَولى اِرتَجي وَلاي باب التَجي وَاللَه...
# 2       العَبد عَبدك يا مَن أَنتَ سَيدهُ وَلَيسَ غَيرك...
# 3       لَو كُنتَ أَطمَع بِالمَنام تَوهما لَسالَت طَيف...
# 4       يعد عَليَّ أَنفاسي ذُنوباً إِذا ما قُلت أَفديه...
# ...                                                   ...
# 254625                   وعندنا ليس محض إلى الشرق أن تولي
# 254626                     من الليالي نهار ومن عتمها ضياء
# 254627                    مقامه إذ تجلى وفي البيد إذ تحلى
# 254628  على بابك انتظرنا وفي البال ألف حيلة من الوصل ل...
# 254629  خذ الصفر لا تبالي فللصفر للرجال وليس في ذاك شي...
#
# [254630 rows x 14 columns]

# %%
has_theme_df = df_copy.dropna(subset=['poem theme'])

# %%
has_theme_df['poem theme'].value_counts()
# Out:
# poem theme
# قصيدة قصيره       25911
# قصيدة عامه        20611
# قصيدة مدح          5165
# قصيدة رومنسيه      4074
# قصيدة حزينه        2277
# قصيدة عتاب         2032
# قصيدة هجاء         1614
# قصيدة غزل          1416
# قصيدة دينية        1186
# قصيدة رثاء          917
# قصيدة شوق           901
# قصيدة فراق          591
# قصيدة ذم            420
# قصيدة وطنيه         343
# قصيدة الاناشيد       28
# قصيدة سياسية         16
# قصيدة المعلقات       10
# قصيدة اعتذار          8
# Name: count, dtype: int64

# %%
theme2labels = {
   'قصيدة حزينه': 0,
   'قصيدة ذم': 1,
   'قصيدة رثاء': 0,
   'قصيدة رومنسيه': 3,
   'قصيدة شوق': 3,
   'قصيدة عتاب': 0,
   'قصيدة غزل': 3,
   'قصيدة فراق': 0,
   'قصيدة مدح': 2,
   'قصيدة هجاء': 1,
 }

labels2theme = [[] for _ in range(len(list(set(theme2labels.values()))))]

for theme, i in theme2labels.items():
  labels2theme[i].append(theme)
labels2theme
# Out:
# [['قصيدة حزينه', 'قصيدة رثاء', 'قصيدة عتاب', 'قصيدة فراق'],
#  ['قصيدة ذم', 'قصيدة هجاء'],
#  ['قصيدة مدح'],
#  ['قصيدة رومنسيه', 'قصيدة شوق', 'قصيدة غزل']]

# %%
excluded_themes = list(set(has_theme_df['poem theme']) - set([item for sublist in labels2theme for item in sublist])) # قصيدة اعتذار has only three poems :)
print(excluded_themes)
has_accepted_theme_df = has_theme_df[has_theme_df['poem theme'].apply(lambda theme: theme not in excluded_themes)]
len(has_accepted_theme_df)
# Out:
# ['قصيدة قصيره', 'قصيدة الاناشيد', 'قصيدة اعتذار', 'قصيدة المعلقات', 'قصيدة دينية', 'قصيدة عامه', 'قصيدة سياسية', 'قصيدة وطنيه']
# 19407

# %%
has_accepted_theme_df['label'] = has_accepted_theme_df['poem theme'].replace(theme2labels)
# Out:
# /tmp/ipykernel_30/351354492.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   has_accepted_theme_df['label'] = has_accepted_theme_df['poem theme'].replace(theme2labels)
# /tmp/ipykernel_30/351354492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_accepted_theme_df['label'] = has_accepted_theme_df['poem theme'].replace(theme2labels)

# %%
def preprocess(verse):
    flattened = re.sub(r'[*&^%.$#@!…ـ)()–:،]', '', verse)
    flattened = re.sub(r'[0-9]', '', flattened)
    flattened = re.sub(r' +', ' ', flattened).strip()
    return flattened

def chunkify_long_poems(verses_list, max_length=64):
  tokens = ' '.join([preprocess(verse) for verse in verses_list]).split(' ')
  return [' '.join(tokens[i*max_length: (i+1)*max_length]) for i in range(len(tokens) // max_length + 1)]

# %%
import re
five_baits_rows = list()
chunk_len = 5
max_len = 0
exc_poems = 0
for index,row in has_accepted_theme_df.iterrows():
  verses = row['poem verses']
  for poem_chunk in chunkify_long_poems(verses):
    five_baits_rows.append({
        'text': poem_chunk,
        'label':row['label'],
        'poem theme': row['poem theme']
      })
  # break
has_accepted_theme_five_baits_df = pd.DataFrame(five_baits_rows)
has_accepted_theme_five_baits_df
# Out:
#                                                     text  label   poem theme
# 0      العَبد عَبدك يا مَن أَنتَ سَيدهُ وَلَيسَ غَيرك...      1     قصيدة ذم
# 1      إِلى السَبع الطِباق عَلا ما خابَ قاصدك الراجي ...      1     قصيدة ذم
# 2      أَوصاف مَجدِكُم أَوَد عِندَ إِدكاري خَير حَمدَ...      1     قصيدة ذم
# 3      مَدحي لِغَيرك في الوَرى تَقليدُ هُوَ صورة وَجَ...      2    قصيدة مدح
# 4      راحَتيهِ الجود كَم صُغت فيكَ مِن القَريض فَرائ...      2    قصيدة مدح
# ...                                                  ...    ...          ...
# 62461  الابتهاج نوى من بهو يالٍ إلى مصي فكم كلما وكم ...      0  قصيدة حزينه
# 62462  فالمحبوب قد وهما فالوجد يولع من في قلبه وله وا...      0  قصيدة حزينه
# 62463  ألا يا راكباً قف لي فواقا هداك الله واستمع الك...      0  قصيدة حزينه
# 62464  ولو تدرون ما أبديتمو لي عتاباً بالملامة أو كلا...      0  قصيدة حزينه
# 62465  ودي ولن نبغي لمهيعهٍ مراما ولن أنساكمو ما عشت ...      0  قصيدة حزينه
#
# [62466 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(x='label', data=has_accepted_theme_five_baits_df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
## calculate class weights
# ## calculating class weights because of label imbalance

# weight_for_0 = (1 / (counts['قبل الإسلام'] + counts['العصر الإسلامي'] + counts['العصر الجاهلي'] + counts['العصر الأموي'])) * (total / 4)
# weight_for_1 = (1 / counts['العصر العباسي']) * (total / 4)
# weight_for_2 = (1 / (counts['العصر المملوكي'] + counts['العصر الأيوبي'] + counts['العصر الفاطمي'])) * (total / 4)
# weight_for_3 = (1 / (counts['العصر الحديث'] + counts['العصر العثماني'])) * (total / 4)


# class_weight = {
#     0: weight_for_0,
#     1: weight_for_1,
#     2: weight_for_2,
#     3: weight_for_3,
# }

# for class_id, weight in class_weight.items():
#     print(f'Weight for class {class_id}: {weight:.2f}')

# %%
theme2labels
# Out:
# {'قصيدة حزينه': 0,
#  'قصيدة ذم': 1,
#  'قصيدة رثاء': 0,
#  'قصيدة رومنسيه': 3,
#  'قصيدة شوق': 3,
#  'قصيدة عتاب': 0,
#  'قصيدة غزل': 3,
#  'قصيدة فراق': 0,
#  'قصيدة مدح': 2,
#  'قصيدة هجاء': 1}

# %%
# min_class = has_accepted_theme_five_baits_df['label'].value_counts().values.min()
# min_class = 500
sample_amounts = {idx:5_000 if cnt > 5_000 else cnt for idx, cnt in has_accepted_theme_five_baits_df['label'].value_counts().items()}
# sample_amounts[2] = min_class
# sample_amounts = {i:(min_class) for i in range(len(labels2theme)) }
print(sample_amounts)
has_accepted_theme_five_baits_df = (
    has_accepted_theme_five_baits_df.groupby('label').apply(lambda g: g.sample(
        # lookup number of samples to take
        n=sample_amounts[g.name],
        # enable replacement if len is less than number of samples expected
        replace=False
    ))
)
# Out:
# {3: 5000, 0: 5000, 2: 5000, 1: 5000}
# /tmp/ipykernel_30/715552627.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   has_accepted_theme_five_baits_df.groupby('label').apply(lambda g: g.sample(

# %%
from sklearn.utils import shuffle
import random

shuffle(has_accepted_theme_five_baits_df,  random_state=20).to_json('/kaggle/working/theme_dataset_from_df.json',force_ascii=False,indent=2,orient='records')
json.dump({'data':json.load(open('/kaggle/working/theme_dataset_from_df.json'))},open('/kaggle/working/theme_dataset.json','w'),indent=4,ensure_ascii=False)

# %%
# !head -10 /kaggle/working/theme_dataset.json
# Out:
# {
#     "data": [
#         {
#             "text": "تَمَتَّع بِها ما ساعفَتكَ وَلا تَكُن عَلَيكَ شَجَىً في الصَدرِ حينَ تَبينُ وَإِن هِيَ أَعطَتكَ اللَيانَ فَإِنَّها لَغَيرِكَ مِن خلّانِها سَتَلينُ وَإِن حَلَفَت لا يَنقُضُ النَأي عَهدَها فَلَيسَ لِمَخضوبِ البَنانِ يَمينُ",
#             "label": 1,
#             "poem theme": "قصيدة هجاء"
#         },
#         {
#             "text": "في ابن الناصر مشت المنونُ إليه غيرَ محصَّنِ ال جَنَباتِ واغتالته غيرَ محاذرِ ولو انتحتْه لأنذرتْه وإنما شبَّ الفجيعةَ أن أُصيبَ بعاثرِ صَرعتْه مسبِلَة الكِمامِ وإنما يقع التحفُّظُ من ذِراعَيْ حاسرِ لم يُنجهِ البيتُ المطنَّبُ بالكوا كبِ والمعمَّدُ بالهلالِ الزاهرِ والنسبةُ العلياءُ إن هي شَجَّرتْ زلِقتْ معارجُها بكلِّ مُفاخرِ وعصائبٌ مضريّةٌ قرشيّةٌ خُلقوا لحفظِ وشائجٍ وأَواصرِ يتراكضون إلى تنجُّزِ ثأرِهم ولو انه عند الغمام",
#             "label": 1,

# %%
import tnkeeh as tn
from datasets import load_dataset
import os
from transformers import AutoTokenizer
import torch
import copy
import tkseem as tk

data_args = {
    'segment' : False,
    'remove_special_chars' : False,
    'remove_english' : True
,    'normalize' : False,
    'remove_diacritics' : True
,    'excluded_chars' : []
  ,  'remove_tatweel' : True
,    'remove_html_elements' : False,
    'remove_links' : False,
    'remove_twitter_meta' : False,
    'remove_long_words' : False,
    'remove_repeated_chars' : False,
}

# more_stop_words = ['وما' , 'فما', 'كنت', 'ولو', 'إلا', 'وإن', 'منك', 'بما', 'وأنت', 'يا', 'لي', 'فلا', 'لنا', 'منهم']
# stop_words = open('/content/list.txt', 'r').read().splitlines() + more_stop_words

def get_tokenizer(tok_name):
    tokenizers = {'SentencePieceTokenizer':tk.SentencePieceTokenizer, 'WordTokenizer':tk.WordTokenizer, 'CharacterTokenizer':tk.CharacterTokenizer,
         'MorphologicalTokenizer':tk.MorphologicalTokenizer, 'RandomTokenizer':tk.RandomTokenizer, 'DisjointLetterTokenizer':tk.DisjointLetterTokenizer}
    return tokenizers[tok_name]


def split_dataset(dataset, seed = 42):
    #create validation split
    if 'valid' not in dataset:
        train_valid_dataset = dataset['train'].train_test_split(test_size=0.1, seed = seed)
        dataset['valid'] = train_valid_dataset.pop('test')
        dataset['train'] = train_valid_dataset['train']

    #create training split
    if 'test' not in dataset:
        train_valid_dataset = dataset['train'].train_test_split(test_size=0.1, seed = seed)
        dataset['test'] = train_valid_dataset.pop('test')
        dataset['train'] = train_valid_dataset['train']
    return dataset


def clean_dataset(dataset):

    cleaner = tn.Tnkeeh(**data_args)
    dataset = cleaner.clean_hf_dataset(dataset, 'text')
    return dataset

def remove_stop_words(example):
    example['text'] = ' '.join([word for word in example['text'].split(' ') if word not in stop_words])

    return example

tokenizer_name = ''
max_tokens = 128
vocab_size  = 10_000

batch_size = 512

# clean and load data
dataset = load_dataset('json',data_files=['/kaggle/working/theme_dataset.json'],field='data')
dataset = clean_dataset(dataset)

dataset = split_dataset(dataset)
# dataset = dataset.map(remove_stop_words)
examples = copy.deepcopy(dataset)


data = []
for sample in dataset['train']:
    data.append(sample['text'])

open(f'/kaggle/working/data.txt', 'w').write(('\n').join(data))
tokenizer = tk.SentencePieceTokenizer
tokenizer = tokenizer(vocab_size = vocab_size)
tokenizer.train('/kaggle/working/data.txt')
dataset = dataset.map(lambda examples:{'input_ids': tokenizer.encode_sentences(examples['text'], out_length= max_tokens)}, batched=True)
columns=['input_ids', 'labels']
dataset = dataset.map(lambda examples:{'labels': examples['label']}, batched=True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Training SentencePiece ...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /kaggle/working/data.txt
#   input_format:
#   model_prefix:
#   model_type: BPE
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: -1
#   eos_id: -1
#   pad_id: 1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: identity
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: /kaggle/working/data.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 16135 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=4398133
# trainer_interface.cc(560) LOG(INFO) Alphabet size=58
# trainer_interface.cc(561) LOG(INFO) Final character coverage=1
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 16135 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 16135
# trainer_interface.cc(609) LOG(INFO) Done! 154648
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=167194 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20381 size=20 all=2055 active=1851 piece=را
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11068 size=40 all=3360 active=3156 piece=▁ما
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7298 size=60 all=4482 active=4278 piece=لم
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5259 size=80 all=6283 active=6079 piece=ته
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4234 size=100 all=7705 active=7501 piece=تي
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4209 min_freq=490
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3635 size=120 all=9154 active=2308 piece=نت
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3075 size=140 all=10785 active=3939 piece=رف
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2588 size=160 all=12729 active=5883 piece=بل
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2339 size=180 all=14232 active=7386 piece=▁الك
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2088 size=200 all=15454 active=8608 piece=وت
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=2081 min_freq=399
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1910 size=220 all=17057 active=2480 piece=▁حتى
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1650 size=240 all=18784 active=4207 piece=ضي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1508 size=260 all=20559 active=5982 piece=شا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1357 size=280 all=21929 active=7352 piece=▁بك
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1248 size=300 all=23558 active=8981 piece=▁كنت
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1243 min_freq=289
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1160 size=320 all=24658 active=2275 piece=عه
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1071 size=340 all=25916 active=3533 piece=▁مثل
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1022 size=360 all=27482 active=5099 piece=▁الظ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=972 size=380 all=28817 active=6434 piece=رم
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=919 size=400 all=30222 active=7839 piece=▁أت
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=918 min_freq=209
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=866 size=420 all=31968 active=3173 piece=▁دون
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=822 size=440 all=33114 active=4319 piece=▁وط
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=761 size=460 all=34777 active=5982 piece=غي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=729 size=480 all=36034 active=7239 piece=قب
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=697 size=500 all=37312 active=8517 piece=▁الأرض
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=696 min_freq=159
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=671 size=520 all=38247 active=2794 piece=▁يم
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=646 size=540 all=39405 active=3952 piece=▁مه
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=619 size=560 all=40783 active=5330 piece=▁شا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=592 size=580 all=42005 active=6552 piece=▁قا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=572 size=600 all=43078 active=7625 piece=▁والع
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=570 min_freq=128
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=551 size=620 all=44303 active=3291 piece=طع
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=531 size=640 all=45132 active=4120 piece=▁البي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=507 size=660 all=46268 active=5256 piece=▁خل
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=490 size=680 all=47491 active=6479 piece=▁سر
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=479 size=700 all=48338 active=7326 piece=▁بالم
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=478 min_freq=109
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=463 size=720 all=49450 active=3435 piece=▁بالأ
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=8940 all=150859 active=7844 piece=ضاض
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=8960 all=151056 active=8041 piece=ظلوم
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=8980 all=151193 active=8178 piece=▁انك
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9000 all=151326 active=8311 piece=▁خيب
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9020 all=151389 active=7622 piece=▁فيح
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9040 all=151532 active=7765 piece=▁يقع
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9060 all=151540 active=7773 piece=▁الإم
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9080 all=151593 active=7826 piece=▁توقد
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9100 all=151593 active=7826 piece=▁صخرة
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9120 all=151622 active=7609 piece=▁فداك
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9140 all=151626 active=7613 piece=▁مسلك
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9160 all=151653 active=7640 piece=▁وفود
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9180 all=151667 active=7654 piece=▁يهفو
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9200 all=151681 active=7668 piece=▁اللحد
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9220 all=151703 active=7607 piece=▁لأنني
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9240 all=151719 active=7623 piece=▁يشتكي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=9260 all=151707 active=7611 piece=▁بالروح
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9280 all=151704 active=7608 piece=ضك
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9300 all=151925 active=7829 piece=عمه
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9320 all=152151 active=7812 piece=▁ضد
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9340 all=152335 active=7996 piece=▁أكا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9360 all=152437 active=8098 piece=▁سدى
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9380 all=152515 active=8176 piece=▁مفل
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9400 all=152580 active=8241 piece=▁أموت
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9420 all=152627 active=7676 piece=▁بمال
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9440 all=152636 active=7685 piece=▁خصيب
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9460 all=152627 active=7676 piece=▁طلوع
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9480 all=152648 active=7697 piece=▁قربى
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9500 all=152662 active=7711 piece=▁مزيد
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9520 all=152666 active=7638 piece=▁وبكل
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9540 all=152711 active=7683 piece=▁يستن
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9560 all=152741 active=7713 piece=▁الصحب
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9580 all=152799 active=7771 piece=▁تجاوز
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9600 all=152785 active=7757 piece=▁غمامة
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9620 all=152805 active=7660 piece=▁يفارق
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9640 all=152791 active=7646 piece=▁العبيد
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=9660 all=152773 active=7628 piece=▁والعلا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9680 all=152913 active=7768 piece=شها
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9700 all=153108 active=7963 piece=يلت
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9720 all=153283 active=7827 piece=غضاء
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9740 all=153452 active=7996 piece=▁بإن
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9760 all=153507 active=8051 piece=▁سند
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9780 all=153589 active=8133 piece=▁لتس
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9800 all=153714 active=8258 piece=▁يحف
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9820 all=153767 active=7735 piece=▁بباب
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9840 all=153783 active=7751 piece=▁جهول
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9860 all=153773 active=7741 piece=▁سموت
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9880 all=153770 active=7738 piece=▁ضمان
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9900 all=153769 active=7737 piece=▁قبول
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9920 all=153799 active=7719 piece=▁مفرد
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=9940 all=153816 active=7736 piece=▁وعلا
# Map:   0%|          | 0/16200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/16200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'poem theme', 'input_ids', 'labels'],
#         num_rows: 16200
#     })
#     valid: Dataset({
#         features: ['text', 'label', 'poem theme', 'input_ids', 'labels'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label', 'poem theme', 'input_ids', 'labels'],
#         num_rows: 1800
#     })
# })

# %%
import tensorflow as tf
import numpy as np
import os
import time
import glob
from tensorflow.keras.layers import GRU, Embedding, Dense, Input, Dropout, Bidirectional, BatchNormalization, Flatten, Reshape
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt



def create_model():
  model = Sequential()
  model.add(Input((max_tokens,)))
  model.add(Embedding(10_000, 128))
  model.add(Bidirectional(GRU(units = 64, return_sequences=True, dropout=0.3)))
  model.add(Bidirectional(GRU(units = 64, return_sequences=True, dropout=0.3)))
  model.add(Bidirectional(GRU(units = 64, dropout=0.3)))
  model.add(Dropout(0.3))
  model.add(Dense(64, activation = 'relu'))
  model.add(Dropout(0.3))
  model.add(Dense(len(labels2theme), activation = 'softmax'))
  model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
  return model


checkpoint_path = "/kaggle/working/saved.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

callbacks = [tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                 monitor='val_accuracy',
                                                 verbose=1,
                                                 save_weights_only=True,
                                                 save_best_only= True,
                                                 mode='max')]

# %%
x_train = np.array(dataset['train']['input_ids'])
y_train = np.array(dataset['train']['labels'])
x_valid = np.array(dataset['valid']['input_ids'])
y_valid = np.array(dataset['valid']['labels'])

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ (None, 128, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_24                │ (None, 128, 128)       │        74,496 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_25                │ (None, 128, 128)       │        74,496 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_26                │ (None, 128)            │        74,496 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,512,004 (5.77 MB)
#  Trainable params: 1,512,004 (5.77 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_train, validation_data = (x_valid, y_valid) , callbacks= callbacks, epochs = 5, shuffle = True, batch_size=4096)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7992 - loss: 0.5755
# Epoch 1: val_accuracy did not improve from 0.34050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7992 - loss: 0.5745 - val_accuracy: 0.3215 - val_loss: 2.3947
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8245 - loss: 0.5002
# Epoch 2: val_accuracy did not improve from 0.34050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8241 - loss: 0.5010 - val_accuracy: 0.3210 - val_loss: 2.6310
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8420 - loss: 0.4571
# Epoch 3: val_accuracy did not improve from 0.34050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8425 - loss: 0.4558 - val_accuracy: 0.3170 - val_loss: 2.8938
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8661 - loss: 0.4011
# Epoch 4: val_accuracy did not improve from 0.34050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8660 - loss: 0.4006 - val_accuracy: 0.3160 - val_loss: 3.0499
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8802 - loss: 0.3639
# Epoch 5: val_accuracy did not improve from 0.34050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8798 - loss: 0.3644 - val_accuracy: 0.3110 - val_loss: 3.1737

# %%
x_test = np.array(dataset['test']['input_ids'])
y_test = np.array(dataset['test']['labels'])

# %%
model = create_model()
model.load_weights(checkpoint_path)
model.evaluate(x_test, y_test, batch_size = 256)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 48 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - accuracy: 0.3456 - loss: 1.9342
# [1.954188585281372, 0.33666667342185974]

# %%
y_pred = model.predict(x_test, batch_size = 256)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 355ms/step

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from bidi.algorithm import get_display
import arabic_reshaper

cm = confusion_matrix(y_test, y_pred.argmax(-1))
print(cm)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
lbls = [get_display(arabic_reshaper.reshape(lbl[0])) for lbl in labels2theme]
df_cm = pd.DataFrame(cmn, lbls, lbls)
plt.figure(figsize=(10,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}, fmt='.2f') # font size

plt.show()
# Out:
# [[120 106 104 110]
#  [ 99 158 107  86]
#  [ 99 110 175 108]
#  [107  81  77 153]]
