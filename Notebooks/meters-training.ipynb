# %%
# !pip install datasets
# !pip install --upgrade arabic-reshaper
# !pip install python-bidi
# !pip install git+https://github.com/ARBML/tnkeeh.git
# !pip install git+https://github.com/ARBML/tkseem.git
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.25.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0
# Requirement already satisfied: python-bidi in /opt/conda/lib/python3.10/site-packages (0.6.0)
# Collecting git+https://github.com/ARBML/tnkeeh.git
#   Cloning https://github.com/ARBML/tnkeeh.git to /tmp/pip-req-build-9hjf8n4c
#   Running command git clone --filter=blob:none --quiet https://github.com/ARBML/tnkeeh.git /tmp/pip-req-build-9hjf8n4c
#   Resolved https://github.com/ARBML/tnkeeh.git to commit f23d505f34030db7dc70b05e1ae3576b5d485725
#   Preparing metadata (setup.py) ... done
# Collecting farasapy (from tnkeeh==0.1.0)
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from tnkeeh==0.1.0) (3.0.0)
# Requirement already satisfied: transformers[sentencepiece] in /opt/conda/lib/python3.10/site-packages (from tnkeeh==0.1.0) (4.44.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->tnkeeh==0.1.0) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (0.25.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets->tnkeeh==0.1.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (0.19.1)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /opt/conda/lib/python3.10/site-packages (from transformers[sentencepiece]->tnkeeh==0.1.0) (0.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->tnkeeh==0.1.0) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets->tnkeeh==0.1.0) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets->tnkeeh==0.1.0) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets->tnkeeh==0.1.0) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->tnkeeh==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->tnkeeh==0.1.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets->tnkeeh==0.1.0) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->tnkeeh==0.1.0) (1.16.0)
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Building wheels for collected packages: tnkeeh
#   Building wheel for tnkeeh (setup.py) ... done
#   Created wheel for tnkeeh: filename=tnkeeh-0.1.0-py3-none-any.whl size=8844 sha256=2a611e66e98af91c7c5f4e7bb7fefafb374e60a58caeada879ef81c03ee9cd3f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qsyhkyxf/wheels/7e/6f/72/82dc0664f6785a5206a12008834fad9f01ab2c9d3aadb0f661
# Successfully built tnkeeh
# Installing collected packages: farasapy, tnkeeh
# Successfully installed farasapy-0.0.14 tnkeeh-0.1.0
# Collecting git+https://github.com/ARBML/tkseem.git
#   Cloning https://github.com/ARBML/tkseem.git to /tmp/pip-req-build-3hrnkl_4
#   Running command git clone --filter=blob:none --quiet https://github.com/ARBML/tkseem.git /tmp/pip-req-build-3hrnkl_4
#   Resolved https://github.com/ARBML/tkseem.git to commit 8532d3c27936b0ee34d79fa48d6e99f2aaef1bc2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (0.2.0)
# Requirement already satisfied: farasapy in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (0.0.14)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (4.66.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tkseem==0.0.3) (1.26.4)
# Collecting black (from tkseem==0.0.3)
#   Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (1.0.0)
# Collecting packaging>=22.0 (from black->tkseem==0.0.3)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting pathspec>=0.9.0 (from black->tkseem==0.0.3)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (3.11.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black->tkseem==0.0.3) (4.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from farasapy->tkseem==0.0.3) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->farasapy->tkseem==0.0.3) (2024.8.30)
# Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.4 MB/s eta 0:00:00a 0:00:01
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.2 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Building wheels for collected packages: tkseem
#   Building wheel for tkseem (setup.py) ... done
#   Created wheel for tkseem: filename=tkseem-0.0.3-py3-none-any.whl size=30855612 sha256=0e0e3fabf4b968c9cfc9bb4db2ad62b8cd70e67a916c2adbc5d6fc578fcc9ae7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kv1dtifd/wheels/3f/51/fe/8ebf98170e16d97756de4084d4492165ec9a4024e1a79c4b32
# Successfully built tkseem
# Installing collected packages: pathspec, packaging, black, tkseem
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.0 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.1 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.0 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed black-24.8.0 packaging-24.1 pathspec-0.12.1 tkseem-0.0.3

# %%
# %load_ext tensorboard

# %%
import pandas as pd
import json
import datasets
ashaar = datasets.load_dataset('arbml/ashaar')
# Out:
# README.md:   0%|          | 0.00/4.71k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/34.7k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/126M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/151M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/254630 [00:00<?, ? examples/s]

# %%
df = ashaar['train'].to_pandas()
df
# Out:
#                        poem title       poem meter  \
# 0       أصبح الملك للذي فطر الخلق       بحر الخفيف
# 1                من أي مولى ارتجي  بحر مجزوء الرمل
# 2       العبد عبدك يا من أنت سيده       بحر البسيط
# 3       لو كنت أطمع بالمنام توهما       بحر الكامل
# 4            يعد علي أنفاسي ذنوبا       بحر الوافر
# ...                           ...              ...
# 254625                       None          المضارع
# 254626                       None          المضارع
# 254627                       None          المضارع
# 254628                       None          المضارع
# 254629                       None          المضارع
#
#                                               poem verses   poem theme  \
# 0       [أَصبَحَ المُلك لِلَّذي فَطر الخَل, قَ بِتَقدي...  قصيدة دينية
# 1       [مِن أَي مَولى اِرتَجي, وَلاي باب التَجي, وَال...  قصيدة دينية
# 2       [العَبد عَبدك يا مَن أَنتَ سَيدهُ, وَلَيسَ غَي...     قصيدة ذم
# 3       [لَو كُنتَ أَطمَع بِالمَنام تَوهما, لَسالَت طَ...   قصيدة عامه
# 4       [يعد عَليَّ أَنفاسي ذُنوباً, إِذا ما قُلت أَفد...   قصيدة عامه
# ...                                                   ...          ...
# 254625                [وعندنا ليس محض, إلى الشرق أن تولي]         None
# 254626                  [من الليالي نهار, ومن عتمها ضياء]         None
# 254627                 [مقامه إذ تجلى, وفي البيد إذ تحلى]         None
# 254628  [على بابك انتظرنا, وفي البال ألف حيلة, من الوص...         None
# 254629  [خذ الصفر لا تبالي, فللصفر للرجال, وليس في ذاك...         None
#
#                                       poem url           poet name  \
# 0       https://www.aldiwan.net/poem16182.html    الامير منجك باشا
# 1       https://www.aldiwan.net/poem16183.html    الامير منجك باشا
# 2       https://www.aldiwan.net/poem16184.html    الامير منجك باشا
# 3       https://www.aldiwan.net/poem16185.html    الامير منجك باشا
# 4       https://www.aldiwan.net/poem16186.html    الامير منجك باشا
# ...                                        ...                 ...
# 254625                                    None  dataset collectors
# 254626                                    None  dataset collectors
# 254627                                    None  dataset collectors
# 254628                                    None  dataset collectors
# 254629                                    None  dataset collectors
#
#                                          poet description  \
# 0       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 1       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 2       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 3       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 4       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# ...                                                   ...
# 254625                                               None
# 254626                                               None
# 254627                                               None
# 254628                                               None
# 254629                                               None
#
#                                                  poet url        poet era  \
# 0       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 1       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 2       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 3       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 4       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# ...                                                   ...             ...
# 254625                                               None            None
# 254626                                               None            None
# 254627                                               None            None
# 254628                                               None            None
# 254629                                               None            None
#
#        poet location poem description poem language type
# 0               None             None               None
# 1               None             None               None
# 2               None             None               None
# 3               None             None               None
# 4               None             None               None
# ...              ...              ...                ...
# 254625          None             None               فصيح
# 254626          None             None               فصيح
# 254627          None             None               فصيح
# 254628          None             None               فصيح
# 254629          None             None               فصيح
#
# [254630 rows x 12 columns]

# %%
# always work on a copy :)
df_copy = df.copy(deep=True)
df_copy['poem count'] = df_copy['poem verses'].apply(lambda poem: len(poem)/2)
df_copy['poem verses str'] = df_copy['poem verses'].apply(lambda verses: ' '.join(verse for verse in verses))
len(df_copy)
# Out:
# 254630

# %%
df_copy
# Out:
#                        poem title       poem meter  \
# 0       أصبح الملك للذي فطر الخلق       بحر الخفيف
# 1                من أي مولى ارتجي  بحر مجزوء الرمل
# 2       العبد عبدك يا من أنت سيده       بحر البسيط
# 3       لو كنت أطمع بالمنام توهما       بحر الكامل
# 4            يعد علي أنفاسي ذنوبا       بحر الوافر
# ...                           ...              ...
# 254625                       None          المضارع
# 254626                       None          المضارع
# 254627                       None          المضارع
# 254628                       None          المضارع
# 254629                       None          المضارع
#
#                                               poem verses   poem theme  \
# 0       [أَصبَحَ المُلك لِلَّذي فَطر الخَل, قَ بِتَقدي...  قصيدة دينية
# 1       [مِن أَي مَولى اِرتَجي, وَلاي باب التَجي, وَال...  قصيدة دينية
# 2       [العَبد عَبدك يا مَن أَنتَ سَيدهُ, وَلَيسَ غَي...     قصيدة ذم
# 3       [لَو كُنتَ أَطمَع بِالمَنام تَوهما, لَسالَت طَ...   قصيدة عامه
# 4       [يعد عَليَّ أَنفاسي ذُنوباً, إِذا ما قُلت أَفد...   قصيدة عامه
# ...                                                   ...          ...
# 254625                [وعندنا ليس محض, إلى الشرق أن تولي]         None
# 254626                  [من الليالي نهار, ومن عتمها ضياء]         None
# 254627                 [مقامه إذ تجلى, وفي البيد إذ تحلى]         None
# 254628  [على بابك انتظرنا, وفي البال ألف حيلة, من الوص...         None
# 254629  [خذ الصفر لا تبالي, فللصفر للرجال, وليس في ذاك...         None
#
#                                       poem url           poet name  \
# 0       https://www.aldiwan.net/poem16182.html    الامير منجك باشا
# 1       https://www.aldiwan.net/poem16183.html    الامير منجك باشا
# 2       https://www.aldiwan.net/poem16184.html    الامير منجك باشا
# 3       https://www.aldiwan.net/poem16185.html    الامير منجك باشا
# 4       https://www.aldiwan.net/poem16186.html    الامير منجك باشا
# ...                                        ...                 ...
# 254625                                    None  dataset collectors
# 254626                                    None  dataset collectors
# 254627                                    None  dataset collectors
# 254628                                    None  dataset collectors
# 254629                                    None  dataset collectors
#
#                                          poet description  \
# 0       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 1       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 2       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 3       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 4       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# ...                                                   ...
# 254625                                               None
# 254626                                               None
# 254627                                               None
# 254628                                               None
# 254629                                               None
#
#                                                  poet url        poet era  \
# 0       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 1       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 2       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 3       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 4       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# ...                                                   ...             ...
# 254625                                               None            None
# 254626                                               None            None
# 254627                                               None            None
# 254628                                               None            None
# 254629                                               None            None
#
#        poet location poem description poem language type  poem count  \
# 0               None             None               None        10.0
# 1               None             None               None        15.0
# 2               None             None               None        12.5
# 3               None             None               None        27.0
# 4               None             None               None        21.0
# ...              ...              ...                ...         ...
# 254625          None             None               فصيح         1.0
# 254626          None             None               فصيح         1.0
# 254627          None             None               فصيح         1.0
# 254628          None             None               فصيح         2.0
# 254629          None             None               فصيح         2.0
#
#                                           poem verses str
# 0       أَصبَحَ المُلك لِلَّذي فَطر الخَل قَ بِتَقديرٍ...
# 1       مِن أَي مَولى اِرتَجي وَلاي باب التَجي وَاللَه...
# 2       العَبد عَبدك يا مَن أَنتَ سَيدهُ وَلَيسَ غَيرك...
# 3       لَو كُنتَ أَطمَع بِالمَنام تَوهما لَسالَت طَيف...
# 4       يعد عَليَّ أَنفاسي ذُنوباً إِذا ما قُلت أَفديه...
# ...                                                   ...
# 254625                   وعندنا ليس محض إلى الشرق أن تولي
# 254626                     من الليالي نهار ومن عتمها ضياء
# 254627                    مقامه إذ تجلى وفي البيد إذ تحلى
# 254628  على بابك انتظرنا وفي البال ألف حيلة من الوصل ل...
# 254629  خذ الصفر لا تبالي فللصفر للرجال وليس في ذاك شي...
#
# [254630 rows x 14 columns]

# %%
has_era_df = df_copy.dropna(subset=['poet era'])

# %%
has_era_df
# Out:
#                        poem title       poem meter  \
# 0       أصبح الملك للذي فطر الخلق       بحر الخفيف
# 1                من أي مولى ارتجي  بحر مجزوء الرمل
# 2       العبد عبدك يا من أنت سيده       بحر البسيط
# 3       لو كنت أطمع بالمنام توهما       بحر الكامل
# 4            يعد علي أنفاسي ذنوبا       بحر الوافر
# ...                           ...              ...
# 160814                       None           الوافر
# 160815                       None           الطويل
# 160816                       None           الطويل
# 160817                       None           الكامل
# 160818                       None           الطويل
#
#                                               poem verses   poem theme  \
# 0       [أَصبَحَ المُلك لِلَّذي فَطر الخَل, قَ بِتَقدي...  قصيدة دينية
# 1       [مِن أَي مَولى اِرتَجي, وَلاي باب التَجي, وَال...  قصيدة دينية
# 2       [العَبد عَبدك يا مَن أَنتَ سَيدهُ, وَلَيسَ غَي...     قصيدة ذم
# 3       [لَو كُنتَ أَطمَع بِالمَنام تَوهما, لَسالَت طَ...   قصيدة عامه
# 4       [يعد عَليَّ أَنفاسي ذُنوباً, إِذا ما قُلت أَفد...   قصيدة عامه
# ...                                                   ...          ...
# 160814  [حــمــتـنـي لذتـي رتـب المـعـالي, وضـــنـــي ...         None
# 160815  [لنــــا كــــل يــــوم رنـــة ونـــوادب, وتــ...         None
# 160816  [أقـول وقـد جاشت لي النفس بالاسى, وحـاجـات صـد...         None
# 160817  [رزء أطــــل فــــجـــل فـــي الارزاء, زفــرات...         None
# 160818  [إذا مـا صـفـاك الدهـر عـيـشـا مـروقا, أصــابـ...         None
#
#                                                poem url         poet name  \
# 0                https://www.aldiwan.net/poem16182.html  الامير منجك باشا
# 1                https://www.aldiwan.net/poem16183.html  الامير منجك باشا
# 2                https://www.aldiwan.net/poem16184.html  الامير منجك باشا
# 3                https://www.aldiwan.net/poem16185.html  الامير منجك باشا
# 4                https://www.aldiwan.net/poem16186.html  الامير منجك باشا
# ...                                                 ...               ...
# 160814  https://poetry.dctabudhabi.ae/diwan/poem/204160  أبو إسحاق الصابي
# 160815  https://poetry.dctabudhabi.ae/diwan/poem/104486  علي شرارة الكتبي
# 160816  https://poetry.dctabudhabi.ae/diwan/poem/104487  علي شرارة الكتبي
# 160817  https://poetry.dctabudhabi.ae/diwan/poem/104488  علي شرارة الكتبي
# 160818  https://poetry.dctabudhabi.ae/diwan/poem/104489  علي شرارة الكتبي
#
#                                          poet description  \
# 0       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 1       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 2       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 3       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# 4       منجك بن محمد بن منجك بن ابي بكر بن عبد القادر ...
# ...                                                   ...
# 160814                                               None
# 160815                                               None
# 160816                                               None
# 160817                                               None
# 160818                                               None
#
#                                                  poet url        poet era  \
# 0       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 1       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 2       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 3       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# 4       https://www.aldiwan.net/cat-poet-alamir-mnczyk...  العصر العثماني
# ...                                                   ...             ...
# 160814      https://poetry.dctabudhabi.ae/diwan/poet/8932   العصر العباسي
# 160815      https://poetry.dctabudhabi.ae/diwan/poet/2131    العصر الحديث
# 160816      https://poetry.dctabudhabi.ae/diwan/poet/2131    العصر الحديث
# 160817      https://poetry.dctabudhabi.ae/diwan/poet/2131    العصر الحديث
# 160818      https://poetry.dctabudhabi.ae/diwan/poet/2131    العصر الحديث
#
#        poet location                                   poem description  \
# 0               None                                               None
# 1               None                                               None
# 2               None                                               None
# 3               None                                               None
# 4               None                                               None
# ...              ...                                                ...
# 160814        العراق  [{'attributes': None, 'children': None, 'name'...
# 160815          None                                               None
# 160816          None                                               None
# 160817          None                                               None
# 160818          None                                               None
#
#        poem language type  poem count  \
# 0                    None        10.0
# 1                    None        15.0
# 2                    None        12.5
# 3                    None        27.0
# 4                    None        21.0
# ...                   ...         ...
# 160814               فصيح         4.0
# 160815               فصيح        30.0
# 160816               فصيح        14.0
# 160817               فصيح        20.0
# 160818               فصيح        26.0
#
#                                           poem verses str
# 0       أَصبَحَ المُلك لِلَّذي فَطر الخَل قَ بِتَقديرٍ...
# 1       مِن أَي مَولى اِرتَجي وَلاي باب التَجي وَاللَه...
# 2       العَبد عَبدك يا مَن أَنتَ سَيدهُ وَلَيسَ غَيرك...
# 3       لَو كُنتَ أَطمَع بِالمَنام تَوهما لَسالَت طَيف...
# 4       يعد عَليَّ أَنفاسي ذُنوباً إِذا ما قُلت أَفديه...
# ...                                                   ...
# 160814  حــمــتـنـي لذتـي رتـب المـعـالي وضـــنـــي بـ...
# 160815  لنــــا كــــل يــــوم رنـــة ونـــوادب وتــنـ...
# 160816  أقـول وقـد جاشت لي النفس بالاسى وحـاجـات صـدري...
# 160817  رزء أطــــل فــــجـــل فـــي الارزاء زفــراتــ...
# 160818  إذا مـا صـفـاك الدهـر عـيـشـا مـروقا أصــابـك ...
#
# [147421 rows x 14 columns]

# %%
has_era_df['poet era'].value_counts()
# Out:
# poet era
# العصر الحديث        55137
# العصر العباسي       30413
# العصر المملوكي      19059
# العصر العثماني      11872
# المغرب والأندلس      6614
# العصر الفاطمي        4939
# العصر الأندلسي       4770
# العصر الأموي         3958
# العصر الأيوبي        3125
# المخضرمين            1975
# العصر الجاهلي        1873
# قبل الإسلام          1786
# عصر بين الدولتين     1416
# العصر الإسلامي        484
# Name: count, dtype: int64

# %% [markdown]
# ### Export era dataset
#
# العصور:
#
#
# | First Header  | Second Header |
# | ------------- | ------------- |
# | 41 - 132 هـ  | العصر الأموي  |
# | 123-232 هـ  | العصر العباسي  |
# |113-172هـ| العصر الأندلسي|
# |358-567 هـ|العصر الفاطمي|
# |569 - 626 هـ|العصر الأيوبي |
# |648-784 هـ |العصر المملوكي|
# |699 - 1200 هـ |العصر العثماني |
# |1200 - now هـ |العصر الحديث |

# %%
counts = has_era_df['poet era'].value_counts().to_dict()
print(counts)
total = 0
for k, v in counts.items():
    total += v
print(total)
# Out:
# {'العصر الحديث': 55137, 'العصر العباسي': 30413, 'العصر المملوكي': 19059, 'العصر العثماني': 11872, 'المغرب والأندلس': 6614, 'العصر الفاطمي': 4939, 'العصر الأندلسي': 4770, 'العصر الأموي': 3958, 'العصر الأيوبي': 3125, 'المخضرمين': 1975, 'العصر الجاهلي': 1873, 'قبل الإسلام': 1786, 'عصر بين الدولتين': 1416, 'العصر الإسلامي': 484}
# 147421

# %%
era2labels = {  
  'العصر العباسي' : 1,
  'العصر الفاطمي': 2,
  'العصر الحديث': 3,
  'العصر العثماني' : 3,
  'العصر الجاهلي' :0,
  'العصر الإسلامي' : 0,
  'العصر الأموي': 0,
  'العصر الأيوبي' : 2,
  'قبل الإسلام' : 0,
  'العصر المملوكي' : 2
}


labels2era = [[] for _ in range(len(list(set(era2labels.values()))))]

for era, i in era2labels.items():
  labels2era[i].append(era)
labels2era
# Out:
# [['العصر الجاهلي', 'العصر الإسلامي', 'العصر الأموي', 'قبل الإسلام'],
#  ['العصر العباسي'],
#  ['العصر الفاطمي', 'العصر الأيوبي', 'العصر المملوكي'],
#  ['العصر الحديث', 'العصر العثماني']]

# %%
# ## calculating class weights because of label imbalance

weight_for_0 = (1 / (counts['قبل الإسلام'] + counts['العصر الإسلامي'] + counts['العصر الجاهلي'] + counts['العصر الأموي'])) * (total / 4)
weight_for_1 = (1 / counts['العصر العباسي']) * (total / 4)
weight_for_2 = (1 / (counts['العصر المملوكي'] + counts['العصر الأيوبي'] + counts['العصر الفاطمي'])) * (total / 4)
weight_for_3 = (1 / (counts['العصر الحديث'] + counts['العصر العثماني'])) * (total / 4)


class_weight = {
    0: weight_for_0,
    1: weight_for_1,
    2: weight_for_2,
    3: weight_for_3,
}

for class_id, weight in class_weight.items():
    print(f'Weight for class {class_id}: {weight:.2f}')
# Out:
# Weight for class 0: 4.55
# Weight for class 1: 1.21
# Weight for class 2: 1.36
# Weight for class 3: 0.55

# %%
excluded_eras = list(set(has_era_df['poet era']) - set([item for sublist in labels2era for item in sublist])) # قصيدة اعتذار has only three poems :)

has_accepted_era_df = has_era_df[has_era_df['poet era'].apply(lambda era: era not in excluded_eras)]
len(has_accepted_era_df)
# Out:
# 132646

# %%
has_accepted_era_df['label'] = has_accepted_era_df['poet era'].replace(era2labels)
# has_accepted_era_df.loc[:, 'label'] = has_accepted_era_df['poet era'].replace(era2labels)
# Out:
# /tmp/ipykernel_31/474790971.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   has_accepted_era_df['label'] = has_accepted_era_df['poet era'].replace(era2labels)
# /tmp/ipykernel_31/474790971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   has_accepted_era_df['label'] = has_accepted_era_df['poet era'].replace(era2labels)

# %%
has_accepted_era_df['label']
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 160814    1
# 160815    3
# 160816    3
# 160817    3
# 160818    3
# Name: label, Length: 132646, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='label', data=has_accepted_era_df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def chunkify_poem(verses_list, max_length=3):
  max_length *= 2 # we need baits not shatrs
  return [verses_list[i:i+max_length] for i in range(0, len(verses_list), max_length) if len(verses_list[i:i+max_length]) == max_length]

# %%
def preprocess(verse):
    flattened = re.sub(r'[*&^%.$#@!…ـ)()–:،]', '', verse)
    flattened = re.sub(r'[0-9]', '', flattened)
    flattened = re.sub(r' +', ' ', flattened).strip()
    return flattened

def chunkify_long_poems(verses_list, max_length=64):
  tokens = ' '.join([preprocess(verse) for verse in verses_list]).split(' ')
  return [' '.join(tokens[i*max_length: (i+1)*max_length]) for i in range(len(tokens) // max_length + 1)]

# %%
import re 
five_baits_rows = list()
chunk_len = 5
max_len = 0 
exc_poems = 0 
for index,row in has_accepted_era_df.iterrows():
  verses = row['poem verses']
  for poem_chunk in chunkify_long_poems(verses):
    five_baits_rows.append({
        'text': poem_chunk,
        'label':row['label'],
        'poet era': row['poet era']
      })
  # break
has_accepted_era_five_baits_df = pd.DataFrame(five_baits_rows)
has_accepted_era_five_baits_df
# Out:
#                                                      text  label  \
# 0       أَصبَحَ المُلك لِلَّذي فَطر الخَل قَ بِتَقديرٍ...      3
# 1       مَدى الدَهر أَخيهِ يَحيى الحصور الكَريمِ أَدرك...      3
# 2       مِن أَي مَولى اِرتَجي وَلاي باب التَجي وَاللَه...      3
# 3       يَلهجِ وَبصنوه عُثمان ذي الن نورَين أَقوم مَنه...      3
# 4       العَبد عَبدك يا مَن أَنتَ سَيدهُ وَلَيسَ غَيرك...      3
# ...                                                   ...    ...
# 323721  إذا ما صفاك الدهر عيشا مروقا أصابك سهم الدهر س...      3
# 323722  مذ طال في الخطى فجاز سما العلياء سمتا ومرتقى و...      3
# 323723  دعاه اللَه لباه مسرعا فسارع فيما قد دعاه تشوقا...      3
# 323724  مفلقا وينظره طوراً يراه متربا ترائبه قد هشمت ع...      3
# 323725     الفردوس حزت نعيمها وملكا رقيب اليوم أعظم مرتقى      3
#
#               poet era
# 0       العصر العثماني
# 1       العصر العثماني
# 2       العصر العثماني
# 3       العصر العثماني
# 4       العصر العثماني
# ...                ...
# 323721    العصر الحديث
# 323722    العصر الحديث
# 323723    العصر الحديث
# 323724    العصر الحديث
# 323725    العصر الحديث
#
# [323726 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(x='label', data=has_accepted_era_five_baits_df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
era2labels
# Out:
# {'العصر العباسي': 1,
#  'العصر الفاطمي': 2,
#  'العصر الحديث': 3,
#  'العصر العثماني': 3,
#  'العصر الجاهلي': 0,
#  'العصر الإسلامي': 0,
#  'العصر الأموي': 0,
#  'العصر الأيوبي': 2,
#  'قبل الإسلام': 0,
#  'العصر المملوكي': 2}

# %%
has_accepted_era_five_baits_df['label'].value_counts().values.min()
# Out:
# 13526

# %%
sample_amounts = {idx:50_000 if cnt > 50_000 else cnt for idx, cnt in has_accepted_era_five_baits_df['label'].value_counts().items()}
print(sample_amounts)
has_accepted_era_five_baits_df = (
    has_accepted_era_five_baits_df.groupby('label').apply(lambda g: g.sample(
        # lookup number of samples to take
        n=sample_amounts[g.name],
        # enable replacement if len is less than number of samples expected
        replace=False  
    ))
)
# Out:
# {3: 50000, 2: 50000, 1: 50000, 0: 13526}
# /tmp/ipykernel_31/2220147854.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   has_accepted_era_five_baits_df.groupby('label').apply(lambda g: g.sample(

# %%
import seaborn as sns
sns.countplot(x='label', data=has_accepted_era_five_baits_df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
from sklearn.utils import shuffle
import random

shuffle(has_accepted_era_five_baits_df,  random_state=20).to_json('/kaggle/working/era_dataset_from_df.json',force_ascii=False,indent=2,orient='records')
json.dump({'data':json.load(open('/kaggle/working/era_dataset_from_df.json'))},open('/kaggle/working/era_dataset.json','w'),indent=4,ensure_ascii=False)

# %%
# !head -10 /kaggle/working/era_dataset.json
# Out:
# {
#     "data": [
#         {
#             "text": "يَقولُ الناسُ لي رَجلٌ سَديدٌ وَما فعلي بِفِعل فتىً سَديدِ إِذا ما كُنتُ ما أَخشى وَعيداً فَما نَفعي مَقالي بِالوَعيدِ",
#             "label": 1,
#             "poet era": "العصر العباسي"
#         },
#         {
#             "text": "فإن الزمانَ أنيقُ الرداء",
#             "label": 1,

# %%
import tnkeeh as tn 
from datasets import load_dataset
import os 
from transformers import AutoTokenizer
import torch
import copy 
import tkseem as tk

data_args = {
    'segment' : False,
    'remove_special_chars' : False,
    'remove_english' : True
,    'normalize' : False,
    'remove_diacritics' : True
,    'excluded_chars' : []
  ,  'remove_tatweel' : True
,    'remove_html_elements' : False,
    'remove_links' : False, 
    'remove_twitter_meta' : False,
    'remove_long_words' : False,
    'remove_repeated_chars' : False,
}

# more_stop_words = ['وما' , 'فما', 'كنت', 'ولو', 'إلا', 'وإن', 'منك', 'بما', 'وأنت', 'يا', 'لي', 'فلا', 'لنا', 'منهم']
# stop_words = open('/content/list.txt', 'r').read().splitlines() + more_stop_words

def get_tokenizer(tok_name):
    tokenizers = {'SentencePieceTokenizer':tk.SentencePieceTokenizer, 'WordTokenizer':tk.WordTokenizer, 'CharacterTokenizer':tk.CharacterTokenizer,
         'MorphologicalTokenizer':tk.MorphologicalTokenizer, 'RandomTokenizer':tk.RandomTokenizer, 'DisjointLetterTokenizer':tk.DisjointLetterTokenizer}
    return tokenizers[tok_name] 


def split_dataset(dataset, seed = 42):
    #create validation split
    if 'valid' not in dataset:
        train_valid_dataset = dataset['train'].train_test_split(test_size=0.1, seed = seed)
        dataset['valid'] = train_valid_dataset.pop('test')
        dataset['train'] = train_valid_dataset['train']

    #create training split 
    if 'test' not in dataset:
        train_valid_dataset = dataset['train'].train_test_split(test_size=0.1, seed = seed)
        dataset['test'] = train_valid_dataset.pop('test')
        dataset['train'] = train_valid_dataset['train']  
    return dataset 


def clean_dataset(dataset):
    
    cleaner = tn.Tnkeeh(**data_args)
    dataset = cleaner.clean_hf_dataset(dataset, 'text')
    return dataset 

def remove_stop_words(example):
    example['text'] = ' '.join([word for word in example['text'].split(' ') if word not in stop_words])
      
    return example

tokenizer_name = ''
max_tokens = 128
vocab_size  = 10000

batch_size = 512

# clean and load data
dataset = load_dataset('json',data_files=['/kaggle/working/era_dataset.json'],field='data')
dataset = clean_dataset(dataset)

dataset = split_dataset(dataset)
# dataset = dataset.map(remove_stop_words)
examples = copy.deepcopy(dataset)


data = []
for sample in dataset['train']:
    data.append(sample['text'])

open(f'/kaggle/working/data.txt', 'w').write(('\n').join(data))
tokenizer = tk.SentencePieceTokenizer
tokenizer = tokenizer(vocab_size = vocab_size)
tokenizer.train('/kaggle/working/data.txt')
dataset = dataset.map(lambda examples:{'input_ids': tokenizer.encode_sentences(examples['text'], out_length= max_tokens)}, batched=True)
columns=['input_ids', 'labels'] 
dataset = dataset.map(lambda examples:{'labels': examples['label']}, batched=True)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/163526 [00:00<?, ? examples/s]
# Training SentencePiece ...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /kaggle/working/data.txt
#   input_format:
#   model_prefix:
#   model_type: BPE
#   vocab_size: 10000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=154 size=9340 all=336467 active=17407 piece=▁البؤس
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=9360 all=336755 active=17695 piece=هدت
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=9380 all=336996 active=17936 piece=▁سيفي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=153 size=9400 all=337078 active=18018 piece=▁وجدوا
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=153 min_freq=48
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=152 size=9420 all=337369 active=17144 piece=▁وبح
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=152 size=9440 all=337508 active=17283 piece=▁الغرا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=9460 all=337723 active=17498 piece=▁تضع
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=9480 all=337932 active=17707 piece=▁ضحكت
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=9500 all=337990 active=17765 piece=▁وكأنها
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=151 min_freq=48
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=150 size=9520 all=338509 active=17419 piece=▁سطر
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=150 size=9540 all=338703 active=17613 piece=▁يقرب
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=9560 all=339145 active=18055 piece=نانه
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=9580 all=339430 active=18340 piece=▁يصيب
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=149 size=9600 all=339463 active=18373 piece=▁النصارى
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=148 min_freq=47
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=148 size=9620 all=340011 active=17522 piece=▁ظعن
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=148 size=9640 all=340184 active=17695 piece=▁لفرط
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=9660 all=340221 active=17732 piece=غان
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=9680 all=340513 active=18024 piece=▁غرور
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=147 size=9700 all=340563 active=18074 piece=▁قلائد
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=147 min_freq=47
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=146 size=9720 all=340715 active=17181 piece=▁زدت
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=146 size=9740 all=341018 active=17484 piece=▁فإنا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=146 size=9760 all=341044 active=17510 piece=▁خلائقه
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=9780 all=341316 active=17782 piece=▁صفي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=9800 all=341433 active=17899 piece=▁فإما
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=145 min_freq=47
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=145 size=9820 all=341553 active=17192 piece=▁النديم
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=9840 all=341912 active=17551 piece=▁مجي
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=9860 all=342055 active=17694 piece=▁لحظا
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=9880 all=342111 active=17750 piece=▁الآراء
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=143 size=9900 all=342420 active=18059 piece=▁لفي
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=143 min_freq=46
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=143 size=9920 all=342534 active=17222 piece=▁يطلع
# Map:   0%|          | 0/132455 [00:00<?, ? examples/s]
# Map:   0%|          | 0/16353 [00:00<?, ? examples/s]
# Map:   0%|          | 0/14718 [00:00<?, ? examples/s]
# Map:   0%|          | 0/132455 [00:00<?, ? examples/s]
# Map:   0%|          | 0/16353 [00:00<?, ? examples/s]
# Map:   0%|          | 0/14718 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'poet era', 'input_ids', 'labels'],
#         num_rows: 132455
#     })
#     valid: Dataset({
#         features: ['text', 'label', 'poet era', 'input_ids', 'labels'],
#         num_rows: 16353
#     })
#     test: Dataset({
#         features: ['text', 'label', 'poet era', 'input_ids', 'labels'],
#         num_rows: 14718
#     })
# })

# %%
# sns.countplot(dataset['train']['label'],orient="v")
sns.countplot(x=dataset['train']['labels'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# <Axes: ylabel='count'>

# %%
from datasets import load_dataset
dt = load_dataset('json',data_files=['/kaggle/working/era_dataset.json'],field='data')
dt
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'poet era'],
#         num_rows: 163526
#     })
# })

# %%
import tensorflow as tf
import numpy as np
import os
import time
import glob
import keras
from tensorflow.keras.layers import GRU, Embedding, Dense, Input, Dropout, Bidirectional, BatchNormalization, Flatten, Reshape
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


num_classes = 4

def create_model():
  model = Sequential()
  model.add(Input((max_tokens,)))
  model.add(Embedding(10_000, 128))
  model.add(Bidirectional(GRU(units = 128, return_sequences=True, dropout=0.3)))
  model.add(Bidirectional(GRU(units = 128, return_sequences=True, dropout=0.3)))
  model.add(Bidirectional(GRU(units = 128, dropout=0.3)))
  model.add(Dropout(0.2))
  model.add(Dense(128, activation = 'relu'))
  model.add(Dropout(0.2))
  model.add(Dense(num_classes, activation = 'softmax'))
  model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
  return model


checkpoint_path = "./weights/saved.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

callbacks = [tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                 monitor='val_accuracy',
                                                 verbose=1,
                                                 save_weights_only=True,
                                                 save_best_only= True,
                                                 mode='max')]

# %%
x_train = np.array(dataset['train']['input_ids'])
y_train = np.array(dataset['train']['labels'])
x_valid = np.array(dataset['valid']['input_ids'])
y_valid = np.array(dataset['valid']['labels'])

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ (None, 128, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_24                │ (None, 128, 256)       │       198,144 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_25                │ (None, 128, 256)       │       296,448 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_26                │ (None, 256)            │       296,448 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,104,452 (8.03 MB)
#  Trainable params: 2,104,452 (8.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train, y_train, validation_data = (x_valid, y_valid) ,epochs = 5, shuffle = True, batch_size=2048, callbacks=callbacks, class_weight=class_weight)
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.1640 - loss: 4.9867
# Epoch 1: val_accuracy improved from -inf to 0.08414, saving model to /kaggle/working/saved.weights.h5
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 40s 488ms/step - accuracy: 0.1635 - loss: 4.9529 - val_accuracy: 0.0841 - val_loss: 1.4787

# %%
x_test = np.array(dataset['test']['input_ids'])
y_test = np.array(dataset['test']['labels'])

# %%
model = create_model()
model.load_weights(checkpoint_path)
model.evaluate(x_test, y_test, batch_size = 256)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 76 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 model = create_model()
# ----> 2 model.load_weights(checkpoint_path)
#       3 model.evaluate(x_test, y_test, batch_size = 256)
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:295, in _raise_loading_failure(error_msgs, warn_only)
#     293     warnings.warn(msg)
#     294 else:
# --> 295     raise ValueError(msg)
#
# ValueError: A total of 8 objects could not be loaded. Example error message for object <Embedding name=embedding_8, built=True>:
#
# Layer 'embedding_8' expected 1 variables, but received 0 variables during loading. Expected: ['embeddings']
#
# List of objects that could not be loaded:
# [<Embedding name=embedding_8, built=True>, <GRUCell name=gru_cell, built=True>, <GRUCell name=gru_cell, built=True>, <GRUCell name=gru_cell, built=True>, <GRUCell name=gru_cell, built=True>, <GRUCell name=gru_cell, built=True>, <GRUCell name=gru_cell, built=True>, <Dense name=dense_16, built=True>]

# %%
y_pred = model.predict(x_test, batch_size = 256)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from bidi.algorithm import get_display
import arabic_reshaper

cm = confusion_matrix(y_test, y_pred.argmax(-1))
print(cm)
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
lbls = [get_display(arabic_reshaper.reshape(lbl[0])) for lbl in labels2era]
df_cm = pd.DataFrame(cmn, lbls, lbls)
plt.figure(figsize=(10,7))
sn.heatmap(df_cm, annot=True, annot_kws={"size": 10}, fmt='.2f') # font size

plt.show()
# Out:
# [[ 793  293   90   24]
#  [ 540 2779 1033  171]
#  [ 236 1179 2592  480]
#  [ 201  670 1488 2149]]
